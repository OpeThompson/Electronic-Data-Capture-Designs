# %%
<h3>StratX CT Summary: Lung Metrics by Lobe</h3>
<table style="border-collapse: collapse; text-align: center; width: 100%;" border="1" cellspacing="0" cellpadding="6">
  <thead style="background-color: #f2f2f2;">
    <tr>
      <th>Lobe</th>
      <th>% Fissure Completeness</th>
      <th>% Voxel Density &lt; -910 HU</th>
      <th>% Voxel Density &lt; -950 HU</th>
      <th>Inspiratory Volume (ml)</th>
    </tr>
  </thead>
  <tbody>
    <tr>
      <td>RUL</td>
      <td>{rul_fissure_completeness}</td>
      <td>{rul_vox_density_910}</td>
      <td>{rul_vox_density_950}</td>
      <td>{rul_insp_volume}</td>
    </tr>
    <tr>
      <td>RUL + RML</td>
      <td>{rul_rml_fissure_completeness}</td>
      <td>{rul_rml_vox_density_910}</td>
      <td>{rul_rml_vox_density_950}</td>
      <td>{rul_rml_insp_volume}</td>
    </tr>
    <tr>
      <td>RML</td>
      <td>{rml_fissure_completeness}</td>
      <td>{rml_vox_density_910}</td>
      <td>{rml_vox_density_950}</td>
      <td>{rml_insp_volume}</td>
    </tr>
    <tr>
      <td>RLL</td>
      <td>{rll_fissure_completeness}</td>
      <td>{rll_vox_density_910}</td>
      <td>{rll_vox_density_950}</td>
      <td>{rll_insp_volume}</td>
    </tr>
    <tr>
      <td>LUL</td>
      <td>{lul_fissure_completeness}</td>
      <td>{lul_vox_density_910}</td>
      <td>{lul_vox_density_950}</td>
      <td>{lul_insp_volume}</td>
    </tr>
    <tr>
      <td>LLL</td>
      <td>{lll_fissure_completeness}</td>
      <td>{lll_vox_density_910}</td>
      <td>{lll_vox_density_950}</td>
      <td>{lll_insp_volume}</td>
    </tr>
  </tbody>
</table>
