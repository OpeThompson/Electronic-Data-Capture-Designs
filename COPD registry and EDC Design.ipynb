# %%
#Action tags
#subject screening
@DEFAULT = concat("COPD-", record_id)
@DEFAULT = concat("COPD-", record_id, "-", floor(random() * 10000))

#medication hx 
@DEFAULT to set predefined values for certain fields.
@HIDECHOICES to hide irrelevant options in specific fields.

#medical hx 
@READONLY to make fields non-editable.
@HIDDEN-SURVEY to hide sensitive fields in the survey view.

#smoking hx
@DEFAULT to calculate initial quit date based on entries.

#px outcome
@DEFAULT to autofill some initial responses.
@READONLY for calculated fields like total scores

# %%
#Branching logic used
#medication hx form
[medication_taken] = "1"  // Displays only if "Yes" is selected for "Medication Taken".

#medical hx
[inflammatory_bowel_disease] = "1"

#smoking hx
[current_smoker] = "2" // Only show questions if the participant no longer smokes.

#px outcome
[worry_last_12_months] = "1" or [worry_last_12_months] = "2"

# %%
#Calculatio fields
#subject screening
"COPD-" + [record_id] + "-" + round(rand() * 10000, 0)
"COPD-" + [record_id] + "-" + left([survey_timestamp], 4)

#smoking hx
[quit_year] - [start_year]

#px outcome
sum([worry_question1], [worry_question2])

#mmrc
if([mmrc_q5] = 1, 5, if([mmrc_q4] = 1, 4, if([mmrc_q3] = 1, 3, if([mmrc_q2] = 1, 2, if([mmrc_q1] = 1, 1, 0)))))

# %%
#piping
#medication hx
What is the dosage of [medication_name]?
Please provide details about your diagnosis of [condition_name].

#medical hx
Please provide details about your diagnosis of [condition_name].

#px outcomes
Based on your responses, your score is [total_score].

#stanford
You reported engaging in [moderate_activity] minutes of moderate activity this week.

#mmrc
Your MMRC Dyspnea Score is [mmrc_total_score].

# %%
#if loop
#smoking hx
if([current_smoker] = "2", [quit_year] - [start_year], "")

#px outcomes
if([food_insecurity_score] >= 4, "Likely Food Insecurity", "No Food Insecurity")

#stanford
if([total_activity_score] < 5, "Low Activity", if([total_activity_score] <= 15, "Moderate Activity", "High Activity"))

#mmrc
if([mmrc_total_score] = 1, "Mild", if([mmrc_total_score] = 2, "Moderate", if([mmrc_total_score] => 3, "Severe"))

# %%
#blood Sample Table 1

<table border="1" cellpadding="5" cellspacing="0" style="border-collapse: collapse; width: 100%;">
    <tr>
        <th>Sample Type</th>
        <th>Number of Tubes</th>
        <th>Total Volume (mL)</th>
    </tr>
    <tr>
        <td>{sample_type}</td>
        <td>{num_tubes}</td>
        <td>{total_volume}</td>
    </tr>
</table>

# %%
#blood sample table 2

<p> </p> 
<table style="border-collapse: collapse; width: 100%;" border="1" cellspacing="0" cellpadding="5"> 
    <tbody> 
        <tr> 
            <th>Type of Sample</th> 
            <th>Number of Tubes</th> 
            <th>Total Volume (mL)</th> 
        </tr> 
        <tr> 
            <td>CPT Tube</td> 
            <td><input style="width: 50px;" name="num_tubes_cpt" type="text"></td> 
            <td><input style="width: 50px;" name="total_volume_cpt" type="text"></td> 
        </tr>
        <tr> 
            <td>Yellow</td> 
            <td><input style="width: 50px;" name="num_tubes_yellow" type="text"></td> 
            <td><input style="width: 50px;" name="total_volume_yellow" type="text"></td> 
        </tr> 
        <tr> 
            <td>Green Top</td> 
            <td><input style="width: 50px;" name="num_tubes_green" type="text"></td> 
            <td><input style="width: 50px;" name="total_volume_green" type="text"></td> 
        </tr> 
        <tr> 
            <td>Purple Top</td> 
            <td><input style="width: 50px;" name="num_tubes_purple" type="text"></td> 
            <td><input style="width: 50px;" name="total_volume_purple" type="text"></td> 
        </tr> 
        <tr> 
            <td>Red Top</td> 
            <td><input style="width: 50px;" name="num_tubes_red" type="text"></td> 
            <td><input style="width: 50px;" name="total_volume_red" type="text"></td> 
        </tr> 
    </tbody> 
</table> 
<p> </p>

# %%
#Processing Table

<table border="1" cellpadding="5" cellspacing="0" style="border-collapse: collapse; width: 100%;">
    <tr>
        <th>Type</th>
        <th>Volume (mL)</th>
        <th># Aliquots</th>
        <th>Stored in Box #</th>
        <th>Time of Initial Spin</th>
        <th>Time Stored</th>
    </tr>
    <tr><td>Plasma/Y</td><td>{plasma_y_vol}</td><td>{plasma_y_aliquots}</td><td>{plasma_y_box}</td><td>{plasma_y_spin}</td><td>{plasma_y_time_stored}</td></tr>
    <tr><td>WB</td><td>{wb_vol}</td><td>{wb_aliquots}</td><td>{wb_box}</td><td>{wb_spin}</td><td>{wb_time_stored}</td></tr>
    <tr><td>DNA</td><td>{dna_vol}</td><td>{dna_aliquots}</td><td>{dna_box}</td><td>{dna_spin}</td><td>{dna_time_stored}</td></tr>
    <tr><td>Buffycoat/Y</td><td>{buffycoat_y_vol}</td><td>{buffycoat_y_aliquots}</td><td>{buffycoat_y_box}</td><td>{buffycoat_y_spin}</td><td>{buffycoat_y_time_stored}</td></tr>
    <tr><td>SERUM</td><td>{serum_vol}</td><td>{serum_aliquots}</td><td>{serum_box}</td><td>{serum_spin}</td><td>{serum_time_stored}</td></tr>
    <tr><td>Plasma/CPT</td><td>{plasma_cpt_vol}</td><td>{plasma_cpt_aliquots}</td><td>{plasma_cpt_box}</td><td>{plasma_cpt_spin}</td><td>{plasma_cpt_time_stored}</td></tr>
    <tr><td>PBMC</td><td>{pbmc_vol}</td><td>{pbmc_aliquots}</td><td>{pbmc_box}</td><td>{pbmc_spin}</td><td>{pbmc_time_stored}</td></tr>
    <tr><td>PBMC/Trizol</td><td>{pbmc_trizol_vol}</td><td>{pbmc_trizol_aliquots}</td><td>{pbmc_trizol_box}</td><td>{pbmc_trizol_spin}</td><td>{pbmc_trizol_time_stored}</td></tr>
    <tr><td>Plasma/G</td><td>{plasma_g_vol}</td><td>{plasma_g_aliquots}</td><td>{plasma_g_box}</td><td>{plasma_g_spin}</td><td>{plasma_g_time_stored}</td></tr>
    <tr><td>BuffyCoat/G</td><td>{buffycoat_g_vol}</td><td>{buffycoat_g_aliquots}</td><td>{buffycoat_g_box}</td><td>{buffycoat_g_spin}</td><td>{buffycoat_g_time_stored}</td></tr>
</table>
<p><strong>Notes:</strong></p>

# %%
#Pulmonary funtion test table

<div class="rich-text-field-label">
    <div class="rich-text-field-label"> 
        <table style="border-collapse: collapse; width: 95.983%; height: 813.333px;" border="1"> 
            <tbody> 
                <tr style="height: 38.6667px;"> 
                    <td style="width: 12.8375%; text-align: center; background-color: #f8cac6;">Test</td> 
                    <td style="width: 18.9506%; text-align: center; background-color: #f8cac6;">Measurement</td> 
                    <td style="width: 23.6882%; text-align: center; background-color: #f8cac6;">Pre BD</td> 
                    <td style="width: 25.2165%; text-align: center; background-color: #f8cac6;">Post BD</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #f8cac6;">Units</td> 
                </tr> 
                <tr style="height: 39.3333px;"> 
                    <td style="background-color: #fbeeb8; width: 12.8375%;" rowspan="2">1. Inspiratory Airway Resistance</td> 
                    <td style="width: 18.9506%; text-align: center; background-color: #fbeeb8;">RAWI</td> 
                    <td style="width: 23.6882%; text-align: center;">{pre_rawi}</td> 
                    <td style="width: 25.2165%; text-align: center;">{post_rawi}</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #fbeeb8;">kPa/L/sec/m¬≤</td> 
                </tr> 
                <tr style="height: 39.3333px;"> 
                    <td style="width: 18.9506%; text-align: center; background-color: #fbeeb8;">SGAW I</td> 
                    <td style="width: 23.6882%; text-align: center;">{pre_sgawi}</td> 
                    <td style="width: 25.2165%; text-align: center;">{post_sgawi}</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #fbeeb8;">L/s/cmH‚ÇÇO/L</td> 
                </tr> 
                <tr style="height: 24.6667px;"> 
                    <td style="width: 12.8375%; background-color: #f8cac6;">&nbsp;</td> 
                    <td style="width: 18.9506%; text-align: center; background-color: #f8cac6;">&nbsp;</td> 
                    <td style="width: 23.6882%; text-align: center; background-color: #f8cac6;">&nbsp;</td> 
                    <td style="width: 25.2165%; text-align: center; background-color: #f8cac6;">&nbsp;</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #f8cac6;">&nbsp;</td> 
                </tr> 
                <tr style="height: 24.6667px;"> 
                    <td style="width: 12.8375%; background-color: #fbeeb8;" rowspan="5">2. Lung Volumes</td> 
                    <td style="width: 18.9506%; text-align: center; background-color: #fbeeb8;">FRC (XX.XX)</td> 
                    <td style="width: 23.6882%; text-align: center;">{pre_frc}</td> 
                    <td style="width: 25.2165%; text-align: center;">{post_frc}</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #fbeeb8;">Liter</td> 
                </tr> 
                <tr style="height: 24.6667px;"> 
                    <td style="width: 18.9506%; text-align: center; background-color: #fbeeb8;">IC (X.XX)</td> 
                    <td style="width: 23.6882%; text-align: center;">{pre_ic}</td> 
                    <td style="width: 25.2165%; text-align: center;">{post_ic}</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #fbeeb8;">Liter</td> 
                </tr> 
                <tr style="height: 24.6667px;"> 
                    <td style="width: 18.9506%; text-align: center; background-color: #fbeeb8;">VC (X.XX)</td> 
                    <td style="width: 23.6882%; text-align: center;">{pre_vc}</td> 
                    <td style="width: 25.2165%; text-align: center;">{post_vc}</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #fbeeb8;">Liter</td> 
                </tr> 
                <tr style="height: 24.6667px;"> 
                    <td style="width: 18.9506%; text-align: center; background-color: #fbeeb8;">RV (XX.XX)</td> 
                    <td style="width: 23.6882%; text-align: center;">{pre_rv}</td> 
                    <td style="width: 25.2165%; text-align: center;">{post_rv}</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #fbeeb8;">Liter</td> 
                </tr> 
                <tr style="height: 24.6667px;"> 
                    <td style="width: 18.9506%; text-align: center; background-color: #fbeeb8;">TLC (XX.XX)</td> 
                    <td style="width: 23.6882%; text-align: center;">{pre_tlc}</td> 
                    <td style="width: 25.2165%; text-align: center;">{post_tlc}</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #fbeeb8;">Liter</td> 
                </tr> 
                <tr style="height: 24.6667px;"> 
                    <td style="width: 12.8375%; background-color: #f8cac6;">&nbsp;</td> 
                    <td style="width: 18.9506%; text-align: center; background-color: #f8cac6;">&nbsp;</td> 
                    <td style="width: 23.6882%; text-align: center; background-color: #f8cac6;">&nbsp;</td> 
                    <td style="width: 25.2165%; text-align: center; background-color: #f8cac6;">&nbsp;</td> 
                    <td style="width: 19.4091%; text-align: center; background-color: #f8cac6;">&nbsp;</td> 
                </tr> 
            </tbody> 
        </table> 
    </div>
</div>
